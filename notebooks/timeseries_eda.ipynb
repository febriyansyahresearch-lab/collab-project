# %% [markdown]
# # Time Series — Forecasting EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from projects.timeseries.src.data import generate_series

# %%
df = generate_series(365)
df.set_index('date')['value'].plot(figsize=(12,4))
plt.show()
