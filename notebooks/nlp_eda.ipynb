# %% [markdown]
# # NLP — Text Classification EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from projects.nlp.src.data import generate_texts

# %%
df = generate_texts(300)
df.head()
df['label'].value_counts()
